# %% [markdown]
# # In this notebook I will be attempting to get a dataset of the # of subway stations in a 1 mile radius for each airbnb listings

# %%
import pandas as pd
from geopy import distance
from ast import literal_eval

# %%
df = pd.read_csv('/content/drive/MyDrive/airbnb/listings_zip.csv')#need the originally dataset for the longitude and latitude coordinates 
sub = pd.read_csv('/content/drive/MyDrive/airbnb/NYC_Transit_Subway_Entrance_And_Exit_Data.csv')# the dataset the contains subway information
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (71) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#              id  ... zipcode
# 0          2595  ...   10018
# 1          3831  ...   11238
# 2          5121  ...   11216
# 3          5136  ...   11232
# 4          5178  ...   10019
# ...         ...  ...     ...
# 46522  44807522  ...   10003
# 46523  44807786  ...   10040
# 46524  44811717  ...   11203
# 46525  44814944  ...   10024
# 46526  44818009  ...   11223
#
# [46527 rows x 72 columns]

# %%
df1
# Out:
#        Unnamed: 0  listing_id  ... High chair  polarity
# 0               0        2595  ...        0.0  0.357882
# 1               1        3831  ...        1.0  0.402653
# 2               2        5121  ...        0.0  0.419562
# 3               3        5136  ...        0.0  0.484073
# 4               4        5178  ...        0.0  0.351055
# ...           ...         ...  ...        ...       ...
# 46487       46522    44807522  ...        0.0  0.000000
# 46488       46523    44807786  ...        0.0  0.000000
# 46489       46524    44811717  ...        0.0  0.000000
# 46490       46525    44814944  ...        0.0  0.000000
# 46491       46526    44818009  ...        0.0  0.000000
#
# [46492 rows x 92 columns]

# %%
sub
# Out:
#      Division  ...        Entrance Location
# 0         BMT  ...   (40.660489, -73.99822)
# 1         BMT  ...  (40.660323, -73.997952)
# 2         BMT  ...  (40.654676, -74.004306)
# 3         BMT  ...  (40.654365, -74.004113)
# 4         BMT  ...   (40.65449, -74.004499)
# ...       ...  ...                      ...
# 1863      IRT  ...  (40.823884, -73.893197)
# 1864      IRT  ...  (40.824118, -73.892731)
# 1865      IRT  ...  (40.903283, -73.850321)
# 1866      IRT  ...   (40.903597, -73.85036)
# 1867      IRT  ...  (40.903509, -73.850124)
#
# [1868 rows x 32 columns]

# %%
dis = distance.distance(literal_eval(sub['Entrance Location'][0]), (df['latitude'][0],df['longitude'][0])).miles

# %%
dis
# Out:
# 6.470882516671042

# %%
x = (df['latitude'][0],df['longitude'][0])

# %%
y = literal_eval(sub['Entrance Location'][0])

# %%
y?

# %% [markdown]
# This is the code that checks and calculates how many subwaystations are in a 1 mile radius for each airbnb listings.

# %%
dist = []
num = 0
for ind in df.index:
  #max = 6000
  print('ind ',ind)
  for index in sub.index:
    #print('index ',index)
    dis = distance.distance( literal_eval(sub['Entrance Location'][index]), (df['latitude'][ind],df['longitude'][ind])).miles
    if dis <= 1 :
      num += 1
  dist.append(num)
  num = 0
  #print(dist)
# Out:
# Streaming output truncated to the last 5000 lines.
# ind  41527
# ind  41528
# ind  41529
# ind  41530
# ind  41531
# ind  41532
# ind  41533
# ind  41534
# ind  41535
# ind  41536
# ind  41537
# ind  41538
# ind  41539
# ind  41540
# ind  41541
# ind  41542
# ind  41543
# ind  41544
# ind  41545
# ind  41546
# ind  41547
# ind  41548
# ind  41549
# ind  41550
# ind  41551
# ind  41552
# ind  41553
# ind  41554
# ind  41555
# ind  41556
# ind  41557
# ind  41558
# ind  41559
# ind  41560
# ind  41561
# ind  41562
# ind  41563
# ind  41564
# ind  41565
# ind  41566
# ind  41567
# ind  41568
# ind  41569
# ind  41570
# ind  41571
# ind  41572
# ind  41573
# ind  41574
# ind  41575
# ind  41576
# ind  41577
# ind  41578
# ind  41579
# ind  41580
# ind  41581
# ind  41582
# ind  41583
# ind  41584
# ind  41585
# ind  41586
# ind  41587
# ind  41588
# ind  41589
# ind  41590
# ind  41591
# ind  41592
# ind  41593
# ind  41594
# ind  41595
# ind  41596
# ind  41597
# ind  41598
# ...

# %%
dist
# Out:
# [260,
#  61,
#  47,
#  27,
#  192,
#  39,
#  109,
#  80,
#  35,
#  50,
#  142,
#  46,
#  35,
#  94,
#  44,
#  43,
#  27,
#  32,
#  29,
#  122,
#  55,
#  49,
#  37,
#  35,
#  81,
#  67,
#  63,
#  43,
#  48,
#  57,
#  28,
#  0,
#  96,
#  214,
#  34,
#  53,
#  35,
#  158,
#  36,
#  126,
#  211,
#  161,
#  31,
#  209,
#  37,
#  84,
#  173,
#  67,
#  71,
#  188,
#  55,
#  64,
#  22,
#  84,
#  49,
#  58,
#  191,
#  57,
#  68,
#  143,
#  35,
#  31,
#  179,
#  35,
#  37,
#  98,
#  31,
#  61,
#  83,
#  32,
#  75,
#  40,
#  70,
#  40,
#  52,
#  42,
#  159,
#  20,
#  42,
#  153,
#  51,
#  39,
#  28,
#  45,
#  69,
#  68,
#  92,
#  213,
#  69,
#  95,
#  33,
#  35,
#  81,
#  42,
#  39,
#  76,
#  84,
#  22,
#  49,
#  55,
#  68,
#  133,
#  35,
#  163,
#  156,
#  9,
#  68,
#  29,
#  71,
#  167,
#  44,
#  106,
#  90,
#  0,
#  31,
#  38,
#  76,
#  53,
#  72,
#  25,
#  156,
#  28,
#  189,
#  64,
#  27,
#  104,
#  30,
#  49,
#  198,
#  43,
#  48,
#  33,
#  111,
#  45,
#  142,
#  21,
#  0,
#  164,
#  65,
# ...

# %%
df['dist'] = dist

# %% [markdown]
# save the dataset

# %%
#Import Drive API and authenticate.
from google.colab import drive

# Mount your Drive to the Colab VM.
#drive.mount('/content/drive')

# Write the DataFrame to CSV file.
with open('/content/drive/MyDrive/airbnb/subwayDataSet1.csv', 'w') as f:
  df.to_csv(f)

# %%
df
# Out:
#              id                            listing_url  ...  zipcode dist
# 0          2595      https://www.airbnb.com/rooms/2595  ...    10018  106
# 1          3831      https://www.airbnb.com/rooms/3831  ...    11238   22
# 2          5121      https://www.airbnb.com/rooms/5121  ...    11216   11
# 3          5136      https://www.airbnb.com/rooms/5136  ...    11232    5
# 4          5178      https://www.airbnb.com/rooms/5178  ...    10019   77
# ...         ...                                    ...  ...      ...  ...
# 46522  44807522  https://www.airbnb.com/rooms/44807522  ...    10003   31
# 46523  44807786  https://www.airbnb.com/rooms/44807786  ...    10040   10
# 46524  44811717  https://www.airbnb.com/rooms/44811717  ...    11203    0
# 46525  44814944  https://www.airbnb.com/rooms/44814944  ...    10024   21
# 46526  44818009  https://www.airbnb.com/rooms/44818009  ...    11223    9
#
# [46527 rows x 73 columns]

# %%
sum(dist) / len(dist)
# Out:
# 20.140864444301158
